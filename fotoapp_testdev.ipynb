# %%
import fotoapp
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
fotoapp.fotosredes('/content/instagram.png',"instagram")
# Out:
# <PIL.Image.Image image mode=RGBA size=1080x720>

# %%
fotoapp.ajustaconstraste('/content/contraste3.jpg')

# %%
fotoapp.filtros('/content/filtros.jpg',"find edges")

# %%
fotoapp.boceto('/content/persona.jpg')
